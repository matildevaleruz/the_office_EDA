# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
lines1 = pd.read_csv("../data/the-office_lines.csv")
lines1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58721 entries, 0 to 58720
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      58721 non-null  int64
#  1   Character       58721 non-null  object
#  2   Line            58721 non-null  object
#  3   Season          58721 non-null  int64
#  4   Episode_Number  58721 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ MB

# %%
nLin = lines1.Character.value_counts().head(10)
nLin
# Out:
# Character
# Michael    11806
# Dwight      7393
# Jim         6666
# Pam         5264
# Andy        3933
# Kevin       1678
# Angela      1677
# Oscar       1464
# Erin        1452
# Ryan        1324
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))

bars = plt.bar(nLin.index, nLin.values)

plt.show()

# %%
linesXs = lines1.pivot(index="Season", columns="Character", values="Line")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 linesXs = lines1.pivot(index="Season", columns="Character", values="Line")
#
# File c:\Python\Lib\site-packages\pandas\core\frame.py:9366, in DataFrame.pivot(self, columns, index, values)
#    9359 @Substitution("")
#    9360 @Appender(_shared_docs["pivot"])
#    9361 def pivot(
#    9362     self, *, columns, index=lib.no_default, values=lib.no_default
#    9363 ) -> DataFrame:
#    9364     from pandas.core.reshape.pivot import pivot
# -> 9366     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\Python\Lib\site-packages\pandas\core\reshape\pivot.py:570, in pivot(data, columns, index, values)
#     566         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     567 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
# ...

# %%
fig, ax = plt.subplots(figsize=(7, 5))

bar_width = 0.25
x = np.arange(len(linesXs.index))
for i, sub_cat in enumerate(linesXs.columns):
    ax.bar(x + i * bar_width, linesXs[sub_cat], width=bar_width, label=sub_cat)

ax.set_xlabel("Category")
ax.set_ylabel("Value")
ax.set_title("Regions - Revenue by Segment", loc="left")
ax.set_xticks(x + bar_width / 2)
ax.set_xticklabels(linesXs.index)
ax.legend(title="Sub Category")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 fig, ax = plt.subplots(figsize=(7, 5))
#       3 bar_width = 0.25
# ----> 4 x = np.arange(len(linesXs.index))
#       5 for i, sub_cat in enumerate(linesXs.columns):
#       6     ax.bar(x + i * bar_width, linesXs[sub_cat], width=bar_width, label=sub_cat)
#
# NameError: name 'linesXs' is not defined
