# %% [markdown]
# ##

# %%
import pandas as pd

# %%
episodios1 = pd.read_csv("../data/the_office_series.csv")
episodios1.info()
episodios1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    188 non-null    int64
#  1   Season        188 non-null    int64
#  2   EpisodeTitle  188 non-null    object
#  3   About         188 non-null    object
#  4   Ratings       188 non-null    float64
#  5   Votes         188 non-null    int64
#  6   Viewership    188 non-null    float64
#  7   Duration      188 non-null    int64
#  8   Date          188 non-null    object
#  9   GuestStars    29 non-null     object
#  10  Director      188 non-null    object
#  11  Writers       188 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 17.8+ KB
#      Unnamed: 0  Season      EpisodeTitle  \
# 0             0       1             Pilot
# 1             1       1     Diversity Day
# 2             2       1       Health Care
# ...

# %%
episodios2 = pd.read_csv("../data/the_office_imdb.csv")
episodios2.info()
episodios2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   season             188 non-null    int64
#  1   episode_num        188 non-null    int64
#  2   title              188 non-null    object
#  3   original_air_date  188 non-null    object
#  4   imdb_rating        188 non-null    float64
#  5   total_votes        188 non-null    int64
#  6   desc               188 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 10.4+ KB
#      season  episode_num             title original_air_date  imdb_rating  \
# 0         1            1             Pilot        2005-03-24          7.4
# 1         1            2     Diversity Day        2005-03-29          8.3
# 2         1            3       Health Care        2005-04-05          7.7
# 3         1            4      The Alliance        2005-04-12          8.0
# ...

# %%
print(episodios1.Votes.sum())
print(episodios2.total_votes.sum()) # tiene más votos/información más reciente
# Out:
# 533587
# 774409

# %%
descripciones = pd.concat([episodios1["About"], episodios2["desc"]], axis = 1)
descripciones
# Out:
#                                                  About  \
# 0    The premiere episode introduces the boss and s...
# 1    Michael's off color remark puts a sensitivity ...
# 2    Michael leaves Dwight in charge of picking the...
# 3    Just for a laugh, Jim agrees to an alliance wi...
# 4    Michael and his staff challenge the warehouse ...
# ..                                                 ...
# 183  Dwight shoots Stanley with a bull tranquilizer...
# 184  The employees hold a paper airplane competitio...
# 185  Dwight becomes regional manager after Andy qui...
# 186  Dwight prepares for a marriage proposal and hi...
# 187  One year later, Dunder Mifflin employees past ...
#
#                                                   desc
# 0    The premiere episode introduces the boss and s...
# 1    Michael's off color remark puts a sensitivity ...
# 2    Michael leaves Dwight in charge of picking the...
# 3    Just for a laugh, Jim agrees to an alliance wi...
# ...

# %%
diferencias = episodios1["About"] != episodios2["desc"]
diferencias.sum()
# Out:
# np.int64(10)

# %%
desc_dif = descripciones[descripciones["About"] != descripciones["desc"]]
desc_dif
# Out:
#                                                  About  \
# 20   Jan comes into the Scranton Branch to give all...
# 23   A routine office day is changed when children ...
# 53   The Dunder Mifflin Infinity website is launchi...
# 63   Dunder-Mifflin participates in a high school j...
# 68   Michael and Holly have sex for the first time,...
# 72   When Michael discovers that corporate has brou...
# 125  Some co-workers who invested in Ryan's Interne...
# 130  When Jim gets an emergency phone call from Hel...
# 171  The office trains Dwight to sell to a female c...
# 176  Dwight tries to keep Daryl from leaving Dunder...
#
#                                                   desc
# 20   Jan comes into the Scranton Branch to give all...
# 23   A routine office day is changed when children ...
# 53   The Dunder Mifflin Infinity website is launchi...
# 63   Dunder Mifflin participates in a high school j...
# 68   Michael and Holly have sex for the first time,...
# ...

# %%
print(descripciones["About"][20])
print(descripciones["desc"][20])
print()
print(descripciones["About"][23])
print(descripciones["desc"][23])
# Out:
# Jan comes into the Scranton Branch to give all the female employees a group seminar on women in the workplace. Upset that he is not allowed in on the proceedings, Michael takes all the men ...
#                     See full summaryÃƒâ€šÃ‚Â Ãƒâ€šÃ‚Â»
# Jan comes into the Scranton Branch to give all the female employees a group seminar on women in the workplace. Upset that he is not allowed in on the proceedings, Michael takes all the men of Dunder Mifflin down into the warehouse for some "guy time" with the warehouse workers. Pam is offered a chance to pursue her dreams of drawing and Roy confronts Jim about his feelings for Pam.
#
# A routine office day is changed when children come to Dunder Mifflin for "Take Your Daughter to Work Day." Michael is surprised when he strikes up a friendship with the five-year old ...
#                     See full summaryÃƒâ€šÃ‚Â Ãƒâ€šÃ‚Â»
# ...

# %%
lines1 = pd.read_csv("../data/the-office_lines.csv")
lines1.info()
lines1 #contiene [direcciones]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58721 entries, 0 to 58720
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      58721 non-null  int64
#  1   Character       58721 non-null  object
#  2   Line            58721 non-null  object
#  3   Season          58721 non-null  int64
#  4   Episode_Number  58721 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ MB
#        Unnamed: 0 Character  \
# 0               0   Michael
# 1               1       Jim
# 2               2   Michael
# 3               3       Jim
# 4               4   Michael
# ...           ...       ...
# 58716       61302     Creed
# 58717       61303  Meredith
# 58718       61304   Phyllis
# 58719       61305       Jim
# 58720       61306       Pam
#
#                                                     Line  Season  \
# 0       All right Jim. Your quarterlies look very goo...       1
# ...

# %%
lines2 = pd.read_csv("../data/The-Office-Lines-V4.csv")
lines2.info()
lines2 # 4k líneas menos(?)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54626 entries, 0 to 54625
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      54626 non-null  int64
#  1   episode     54626 non-null  int64
#  2   title       54626 non-null  object
#  3   scene       54626 non-null  int64
#  4   speaker     54626 non-null  object
#  5   line        54626 non-null  object
#  6   Unnamed: 6  17 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 2.9+ MB
#        season  episode   title  scene   speaker  \
# 0           1        1   Pilot      1   Michael
# 1           1        1   Pilot      1       Jim
# 2           1        1   Pilot      1   Michael
# 3           1        1   Pilot      1       Jim
# 4           1        1   Pilot      1   Michael
# ...       ...      ...     ...    ...       ...
# 54621       9       24  Finale   8153     Creed
# 54622       9       24  Finale   8154  Meredith
# ...

# %%
lines2["Unnamed: 6"].value_counts()
# Out:
# Unnamed: 6
# how are you?                                                                                                          1
# Alan and I will conduct your performance review over the phone tomorrow.                                              1
# I'm good. I can go home now.                                                                                          1
# can we please not talk about paper? There's gotta be something else we can talk about.                                1
# I'm stopping the car.                                                                                                 1
# Michael told us.                                                                                                      1
# we're renting Charlotte's Web.                                                                                        1
# that's a twelve hundred dollar stroller.                                                                              1
# ...

# %%
lindif = lines1.Line != lines2.line
lindif.sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 lindif = lines1.Line != lines2.line
#       2 lindif.sum()
#
# File c:\Python\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Python\Lib\site-packages\pandas\core\arraylike.py:44, in OpsMixin.__ne__(self, other)
#      42 @unpack_zerodim_and_defer("__ne__")
#      43 def __ne__(self, other):
# ---> 44     return self._cmp_method(other, operator.ne)
#
# File c:\Python\Lib\site-packages\pandas\core\series.py:6133, in Series._cmp_method(self, other, op)
#    6130 res_name = ops.get_op_result_name(self, other)
#    6132 if isinstance(other, Series) and not self._indexed_same(other):
# ...

# %%
lines1.Character.nunique()
# Out:
# 780

# %%
lines2.speaker.nunique()
# Out:
# 775

# %%
lines1.Character.value_counts().reset_index().head(10)
# Out:
#   Character  count
# 0   Michael  11806
# 1    Dwight   7393
# 2       Jim   6666
# 3       Pam   5264
# 4      Andy   3933
# 5     Kevin   1678
# 6    Angela   1677
# 7     Oscar   1464
# 8      Erin   1452
# 9      Ryan   1324

# %%
lines2.speaker.value_counts().reset_index().head(10)
# Out:
#    speaker  count
# 0  Michael  10773
# 1   Dwight   6752
# 2      Jim   6222
# 3      Pam   4973
# 4     Andy   3698
# 5    Kevin   1535
# 6   Angela   1534
# 7     Erin   1413
# 8    Oscar   1336
# 9     Ryan   1182

# %%
https://www.screentimecentral.com/tv-the-office
